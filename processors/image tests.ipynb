# %%
import meta.models;

# %%
meta.models.Image.objects.all()
# Out:
# [id: 1
# service: serviceinstance - tasks.add_sample_data [1]
# name: Oxford Codrington Library
# objectId: 9415078c-3a73-414d-af98-2c4772c55e13
# newerVersion: None
# fileFormat: zoom
# pixelFormat: b
# imageWidth: 999
# imageHeight: 749
# numberColorBands: 3
# imageURL: http://localhost:80/images/camelot-UK_2012OxfordUniversity-42/
# camera: None
# , id: 2
# service: serviceinstance - tasks.add_sample_images [2]
# name: Purdue Data Date:20100427161936 Sequence:04003 Camera:0 Frame:000
# objectId: 6088d129-0ec4-492c-9424-4b6479ad39f1
# newerVersion: None
# fileFormat: zoom
# pixelFormat: b
# imageWidth: 3248
# imageHeight: 4872
# numberColorBands: 1
# imageURL: http://localhost:80/images/20100427161936-04003000-00-VIS/
# camera: None
# , id: 3
# service: serviceinstance - tasks.add_sample_images [2]
# name: Purdue Data Date:20100427161936 Sequence:04003 Camera:1 Frame:000
# objectId: d05bcf7e-be3a-4a73-be4d-24aff4695f9f
# newerVersion: None
# fileFormat: zoom
# pixelFormat: b
# ...

# %%
meta.models.ImageCollection.objects.all()
# Out:
# [id: 1
# service: serviceinstance - tasks.add_sample_data [1]
# name: Oxford Libraries
# objectId: a2b2b0e9-8031-4f1f-9b84-702821fc52ce
# newerVersion: None
# images
#   Oxford Codrington Library[1]
# , id: 2
# service: serviceinstance - tasks.add_sample_images [2]
# name: Purdue Dataset Camera 0
# objectId: f21ddeda-a2a7-4643-b61b-d5960bf8590c
# newerVersion: None
# images
#   Purdue Data Date:20100427161936 Sequence:04003 Camera:0 Frame:000[2]
#   Purdue Data Date:20100427161937 Sequence:04003 Camera:0 Frame:001[8]
#   Purdue Data Date:20100427161937 Sequence:04003 Camera:0 Frame:002[14]
#   Purdue Data Date:20100427161938 Sequence:04003 Camera:0 Frame:003[20]
#   Purdue Data Date:20100427161939 Sequence:04003 Camera:0 Frame:004[26]
#   Purdue Data Date:20100427161940 Sequence:04003 Camera:0 Frame:005[32]
#   Purdue Data Date:20100427161941 Sequence:04003 Camera:0 Frame:006[38]
#   Purdue Data Date:20100427161941 Sequence:04003 Camera:0 Frame:007[44]
# ...
