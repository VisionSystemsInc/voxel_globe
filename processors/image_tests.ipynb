# %%
import meta.models;

# %%
meta.models.Image.objects.all()
# Out:
# [id: 1
# service: serviceinstance - tasks.add_sample_images [2]
# name: Purdue Data Date:20100427161936 Sequence:04003 Camera:0 Frame:000
# objectId: 4faa25d7-d1d3-485e-aa7d-1ba0e362d961
# newerVersion: None
# deleted: False
# fileFormat: zoom
# pixelFormat: b
# imageWidth: 3248
# imageHeight: 4872
# numberColorBands: 1
# imageURL: http://localhost:8080/images/20100427161936-04003000-00-VIS/
# camera: camera - 20100427161936-04003000-00-VIS[121]
# , id: 2
# service: serviceinstance - tasks.add_sample_images [2]
# name: Purdue Data Date:20100427161936 Sequence:04003 Camera:1 Frame:000
# objectId: 98370036-f92f-4e4d-8d28-e86ab4217932
# newerVersion: None
# deleted: False
# fileFormat: zoom
# pixelFormat: b
# imageWidth: 3248
# imageHeight: 4872
# numberColorBands: 1
# imageURL: http://localhost:8080/images/20100427161936-04003000-01-VIS/
# camera: camera - 20100427161936-04003000-01-VIS[122]
# , id: 3
# service: serviceinstance - tasks.add_sample_images [2]
# name: Purdue Data Date:20100427161936 Sequence:04003 Camera:2 Frame:000
# objectId: 8e1fe35c-ad62-449b-871f-2c3afcc1bbd3
# newerVersion: None
# deleted: False
# fileFormat: zoom
# pixelFormat: b
# imageWidth: 3248
# imageHeight: 4872
# numberColorBands: 1
# imageURL: http://localhost:8080/images/20100427161936-04003000-02-VIS/
# camera: camera - 20100427161936-04003000-02-VIS[123]
# , id: 4
# service: serviceinstance - tasks.add_sample_images [2]
# name: Purdue Data Date:20100427161936 Sequence:04003 Camera:3 Frame:000
# objectId: 82d166b0-2ce2-47e8-bced-cb7ea417ddd7
# newerVersion: None
# deleted: False
# fileFormat: zoom
# pixelFormat: b
# imageWidth: 3248
# imageHeight: 4872
# numberColorBands: 1
# imageURL: http://localhost:8080/images/20100427161936-04003000-03-VIS/
# camera: camera - 20100427161936-04003000-03-VIS[124]
# , id: 5
# service: serviceinstance - tasks.add_sample_images [2]
# name: Purdue Data Date:20100427161936 Sequence:04003 Camera:4 Frame:000
# objectId: 8815d7e4-a43d-4b1f-8f02-f9d42d517ab4
# newerVersion: None
# deleted: False
# fileFormat: zoom
# pixelFormat: b
# imageWidth: 3248
# imageHeight: 4872
# numberColorBands: 1
# imageURL: http://localhost:8080/images/20100427161936-04003000-04-VIS/
# camera: camera - 20100427161936-04003000-04-VIS[125]
# , id: 6
# service: serviceinstance - tasks.add_sample_images [2]
# name: Purdue Data Date:20100427161936 Sequence:04003 Camera:5 Frame:000
# objectId: 52ec4b5b-f5b7-48ee-952b-289160e2a046
# newerVersion: None
# deleted: False
# fileFormat: zoom
# pixelFormat: b
# imageWidth: 3248
# imageHeight: 4872
# numberColorBands: 1
# imageURL: http://localhost:8080/images/20100427161936-04003000-05-VIS/
# camera: camera - 20100427161936-04003000-05-VIS[126]
# , id: 7
# service: serviceinstance - tasks.add_sample_images [2]
# name: Purdue Data Date:20100427161937 Sequence:04003 Camera:0 Frame:001
# objectId: f30b80b7-33f9-4f4b-affa-c86f80591338
# newerVersion: None
# deleted: False
# fileFormat: zoom
# pixelFormat: b
# imageWidth: 3248
# imageHeight: 4872
# numberColorBands: 1
# imageURL: http://localhost:8080/images/20100427161937-04003001-00-VIS/
# camera: camera - 20100427161937-04003001-00-VIS[127]
# , id: 13
# service: serviceinstance - tasks.add_sample_images [2]
# name: Purdue Data Date:20100427161937 Sequence:04003 Camera:0 Frame:002
# objectId: e587d37d-d8a7-4fbe-a676-4121a7cf090b
# newerVersion: None
# deleted: False
# fileFormat: zoom
# pixelFormat: b
# imageWidth: 3248
# imageHeight: 4872
# numberColorBands: 1
# imageURL: http://localhost:8080/images/20100427161937-04003002-00-VIS/
# camera: camera - 20100427161937-04003002-00-VIS[133]
# , id: 8
# service: serviceinstance - tasks.add_sample_images [2]
# name: Purdue Data Date:20100427161937 Sequence:04003 Camera:1 Frame:001
# objectId: eac1d68f-a808-4504-9800-f48f47dc438d
# newerVersion: None
# deleted: False
# fileFormat: zoom
# pixelFormat: b
# imageWidth: 3248
# imageHeight: 4872
# numberColorBands: 1
# imageURL: http://localhost:8080/images/20100427161937-04003001-01-VIS/
# camera: camera - 20100427161937-04003001-01-VIS[128]
# , id: 14
# service: serviceinstance - tasks.add_sample_images [2]
# name: Purdue Data Date:20100427161937 Sequence:04003 Camera:1 Frame:002
# objectId: 978e190b-6604-44c4-a758-cd6e25800716
# newerVersion: None
# deleted: False
# fileFormat: zoom
# pixelFormat: b
# imageWidth: 3248
# imageHeight: 4872
# numberColorBands: 1
# imageURL: http://localhost:8080/images/20100427161937-04003002-01-VIS/
# camera: camera - 20100427161937-04003002-01-VIS[134]
# , id: 9
# service: serviceinstance - tasks.add_sample_images [2]
# name: Purdue Data Date:20100427161937 Sequence:04003 Camera:2 Frame:001
# objectId: e360390b-e03b-46b1-8c61-7eb41e1e5731
# newerVersion: None
# deleted: False
# fileFormat: zoom
# pixelFormat: b
# imageWidth: 3248
# imageHeight: 4872
# numberColorBands: 1
# imageURL: http://localhost:8080/images/20100427161937-04003001-02-VIS/
# camera: camera - 20100427161937-04003001-02-VIS[129]
# , id: 15
# service: serviceinstance - tasks.add_sample_images [2]
# name: Purdue Data Date:20100427161937 Sequence:04003 Camera:2 Frame:002
# objectId: 1fd4bd11-1cb3-479c-98c1-27fb3346f53b
# newerVersion: None
# deleted: False
# fileFormat: zoom
# pixelFormat: b
# imageWidth: 3248
# imageHeight: 4872
# numberColorBands: 1
# imageURL: http://localhost:8080/images/20100427161937-04003002-02-VIS/
# camera: camera - 20100427161937-04003002-02-VIS[135]
# , id: 10
# service: serviceinstance - tasks.add_sample_images [2]
# name: Purdue Data Date:20100427161937 Sequence:04003 Camera:3 Frame:001
# objectId: f5ced66d-302c-478f-ba14-cd63aa6e6e5c
# newerVersion: None
# deleted: False
# fileFormat: zoom
# pixelFormat: b
# imageWidth: 3248
# imageHeight: 4872
# numberColorBands: 1
# imageURL: http://localhost:8080/images/20100427161937-04003001-03-VIS/
# camera: camera - 20100427161937-04003001-03-VIS[130]
# , id: 16
# service: serviceinstance - tasks.add_sample_images [2]
# name: Purdue Data Date:20100427161937 Sequence:04003 Camera:3 Frame:002
# objectId: f7eb979c-364b-4ebd-ad30-616ec3404a20
# newerVersion: None
# deleted: False
# fileFormat: zoom
# pixelFormat: b
# imageWidth: 3248
# imageHeight: 4872
# numberColorBands: 1
# imageURL: http://localhost:8080/images/20100427161937-04003002-03-VIS/
# camera: camera - 20100427161937-04003002-03-VIS[136]
# , id: 11
# service: serviceinstance - tasks.add_sample_images [2]
# name: Purdue Data Date:20100427161937 Sequence:04003 Camera:4 Frame:001
# objectId: bc5f88ef-41ed-4777-95ef-535d5701ac63
# newerVersion: None
# deleted: False
# fileFormat: zoom
# pixelFormat: b
# imageWidth: 3248
# imageHeight: 4872
# numberColorBands: 1
# imageURL: http://localhost:8080/images/20100427161937-04003001-04-VIS/
# camera: camera - 20100427161937-04003001-04-VIS[131]
# , id: 17
# service: serviceinstance - tasks.add_sample_images [2]
# name: Purdue Data Date:20100427161937 Sequence:04003 Camera:4 Frame:002
# objectId: 13258fbb-0eb4-4ace-b4a4-abc87ceb82fc
# newerVersion: None
# deleted: False
# fileFormat: zoom
# pixelFormat: b
# imageWidth: 3248
# imageHeight: 4872
# numberColorBands: 1
# imageURL: http://localhost:8080/images/20100427161937-04003002-04-VIS/
# camera: camera - 20100427161937-04003002-04-VIS[137]
# , id: 12
# service: serviceinstance - tasks.add_sample_images [2]
# name: Purdue Data Date:20100427161937 Sequence:04003 Camera:5 Frame:001
# objectId: 3eff7db7-5eb5-4b6f-83e2-fb79c93fd903
# newerVersion: None
# deleted: False
# fileFormat: zoom
# pixelFormat: b
# imageWidth: 3248
# imageHeight: 4872
# numberColorBands: 1
# imageURL: http://localhost:8080/images/20100427161937-04003001-05-VIS/
# camera: camera - 20100427161937-04003001-05-VIS[132]
# , id: 18
# service: serviceinstance - tasks.add_sample_images [2]
# name: Purdue Data Date:20100427161937 Sequence:04003 Camera:5 Frame:002
# objectId: 411d36b8-373e-479c-ad72-6455b12d8cd5
# newerVersion: None
# deleted: False
# fileFormat: zoom
# pixelFormat: b
# imageWidth: 3248
# imageHeight: 4872
# numberColorBands: 1
# imageURL: http://localhost:8080/images/20100427161937-04003002-05-VIS/
# camera: camera - 20100427161937-04003002-05-VIS[138]
# , id: 19
# service: serviceinstance - tasks.add_sample_images [2]
# name: Purdue Data Date:20100427161938 Sequence:04003 Camera:0 Frame:003
# objectId: 2ce05d78-89f4-4628-b42c-a823483deadf
# newerVersion: None
# deleted: False
# fileFormat: zoom
# pixelFormat: b
# imageWidth: 3248
# imageHeight: 4872
# numberColorBands: 1
# imageURL: http://localhost:8080/images/20100427161938-04003003-00-VIS/
# camera: camera - 20100427161938-04003003-00-VIS[139]
# , id: 20
# service: serviceinstance - tasks.add_sample_images [2]
# name: Purdue Data Date:20100427161938 Sequence:04003 Camera:1 Frame:003
# objectId: 5169d848-074b-44e2-b12b-bd084d57f8dc
# newerVersion: None
# deleted: False
# fileFormat: zoom
# pixelFormat: b
# imageWidth: 3248
# imageHeight: 4872
# numberColorBands: 1
# imageURL: http://localhost:8080/images/20100427161938-04003003-01-VIS/
# camera: camera - 20100427161938-04003003-01-VIS[140]
# , '...(remaining elements truncated)...']

# %%
meta.models.ImageCollection.objects.all()
# Out:
# [id: 1
# service: serviceinstance - tasks.add_sample_images [2]
# name: Purdue Dataset Camera 0
# objectId: 3c445a0b-770b-4b41-85e1-cabcc4c03ac0
# newerVersion: None
# deleted: False
# images
#   Purdue Data Date:20100427161936 Sequence:04003 Camera:0 Frame:000[1]
#   Purdue Data Date:20100427161937 Sequence:04003 Camera:0 Frame:001[7]
#   Purdue Data Date:20100427161937 Sequence:04003 Camera:0 Frame:002[13]
#   Purdue Data Date:20100427161938 Sequence:04003 Camera:0 Frame:003[19]
#   Purdue Data Date:20100427161939 Sequence:04003 Camera:0 Frame:004[25]
#   Purdue Data Date:20100427161940 Sequence:04003 Camera:0 Frame:005[31]
#   Purdue Data Date:20100427161941 Sequence:04003 Camera:0 Frame:006[37]
#   Purdue Data Date:20100427161941 Sequence:04003 Camera:0 Frame:007[43]
#   Purdue Data Date:20100427161942 Sequence:04003 Camera:0 Frame:008[49]
#   Purdue Data Date:20100427161943 Sequence:04003 Camera:0 Frame:009[55]
# , id: 2
# service: serviceinstance - tasks.add_sample_images [2]
# name: Purdue Dataset Camera 1
# objectId: 1502a1ff-5fb2-4fe8-8ddd-85f5c3dd07b2
# newerVersion: None
# deleted: False
# images
#   Purdue Data Date:20100427161936 Sequence:04003 Camera:1 Frame:000[2]
#   Purdue Data Date:20100427161937 Sequence:04003 Camera:1 Frame:001[8]
#   Purdue Data Date:20100427161937 Sequence:04003 Camera:1 Frame:002[14]
#   Purdue Data Date:20100427161938 Sequence:04003 Camera:1 Frame:003[20]
#   Purdue Data Date:20100427161939 Sequence:04003 Camera:1 Frame:004[26]
#   Purdue Data Date:20100427161940 Sequence:04003 Camera:1 Frame:005[32]
#   Purdue Data Date:20100427161941 Sequence:04003 Camera:1 Frame:006[38]
#   Purdue Data Date:20100427161941 Sequence:04003 Camera:1 Frame:007[44]
#   Purdue Data Date:20100427161942 Sequence:04003 Camera:1 Frame:008[50]
#   Purdue Data Date:20100427161943 Sequence:04003 Camera:1 Frame:009[56]
# , id: 3
# service: serviceinstance - tasks.add_sample_images [2]
# name: Purdue Dataset Camera 2
# objectId: 4c088892-bed2-47f4-a172-df74241aa99d
# newerVersion: None
# deleted: False
# images
#   Purdue Data Date:20100427161936 Sequence:04003 Camera:2 Frame:000[3]
#   Purdue Data Date:20100427161937 Sequence:04003 Camera:2 Frame:001[9]
#   Purdue Data Date:20100427161937 Sequence:04003 Camera:2 Frame:002[15]
#   Purdue Data Date:20100427161938 Sequence:04003 Camera:2 Frame:003[21]
#   Purdue Data Date:20100427161939 Sequence:04003 Camera:2 Frame:004[27]
#   Purdue Data Date:20100427161940 Sequence:04003 Camera:2 Frame:005[33]
#   Purdue Data Date:20100427161941 Sequence:04003 Camera:2 Frame:006[39]
#   Purdue Data Date:20100427161941 Sequence:04003 Camera:2 Frame:007[45]
#   Purdue Data Date:20100427161942 Sequence:04003 Camera:2 Frame:008[51]
#   Purdue Data Date:20100427161943 Sequence:04003 Camera:2 Frame:009[57]
# , id: 4
# service: serviceinstance - tasks.add_sample_images [2]
# name: Purdue Dataset Camera 3
# objectId: 6e2a1df4-a73c-4b73-9c5b-2232c68cfc7e
# newerVersion: None
# deleted: False
# images
#   Purdue Data Date:20100427161936 Sequence:04003 Camera:3 Frame:000[4]
#   Purdue Data Date:20100427161937 Sequence:04003 Camera:3 Frame:001[10]
#   Purdue Data Date:20100427161937 Sequence:04003 Camera:3 Frame:002[16]
#   Purdue Data Date:20100427161938 Sequence:04003 Camera:3 Frame:003[22]
#   Purdue Data Date:20100427161939 Sequence:04003 Camera:3 Frame:004[28]
#   Purdue Data Date:20100427161940 Sequence:04003 Camera:3 Frame:005[34]
#   Purdue Data Date:20100427161941 Sequence:04003 Camera:3 Frame:006[40]
#   Purdue Data Date:20100427161941 Sequence:04003 Camera:3 Frame:007[46]
#   Purdue Data Date:20100427161942 Sequence:04003 Camera:3 Frame:008[52]
#   Purdue Data Date:20100427161943 Sequence:04003 Camera:3 Frame:009[58]
# , id: 5
# service: serviceinstance - tasks.add_sample_images [2]
# name: Purdue Dataset Camera 4
# objectId: 093cabca-8876-45c6-a64b-8881942f5283
# newerVersion: None
# deleted: False
# images
#   Purdue Data Date:20100427161936 Sequence:04003 Camera:4 Frame:000[5]
#   Purdue Data Date:20100427161937 Sequence:04003 Camera:4 Frame:001[11]
#   Purdue Data Date:20100427161937 Sequence:04003 Camera:4 Frame:002[17]
#   Purdue Data Date:20100427161938 Sequence:04003 Camera:4 Frame:003[23]
#   Purdue Data Date:20100427161939 Sequence:04003 Camera:4 Frame:004[29]
#   Purdue Data Date:20100427161940 Sequence:04003 Camera:4 Frame:005[35]
#   Purdue Data Date:20100427161941 Sequence:04003 Camera:4 Frame:006[41]
#   Purdue Data Date:20100427161941 Sequence:04003 Camera:4 Frame:007[47]
#   Purdue Data Date:20100427161942 Sequence:04003 Camera:4 Frame:008[53]
#   Purdue Data Date:20100427161943 Sequence:04003 Camera:4 Frame:009[59]
# , id: 6
# service: serviceinstance - tasks.add_sample_images [2]
# name: Purdue Dataset Camera 5
# objectId: b7007f18-1304-4039-a192-912a080c1cdf
# newerVersion: None
# deleted: False
# images
#   Purdue Data Date:20100427161936 Sequence:04003 Camera:5 Frame:000[6]
#   Purdue Data Date:20100427161937 Sequence:04003 Camera:5 Frame:001[12]
#   Purdue Data Date:20100427161937 Sequence:04003 Camera:5 Frame:002[18]
#   Purdue Data Date:20100427161938 Sequence:04003 Camera:5 Frame:003[24]
#   Purdue Data Date:20100427161939 Sequence:04003 Camera:5 Frame:004[30]
#   Purdue Data Date:20100427161940 Sequence:04003 Camera:5 Frame:005[36]
#   Purdue Data Date:20100427161941 Sequence:04003 Camera:5 Frame:006[42]
#   Purdue Data Date:20100427161941 Sequence:04003 Camera:5 Frame:007[48]
#   Purdue Data Date:20100427161942 Sequence:04003 Camera:5 Frame:008[54]
#   Purdue Data Date:20100427161943 Sequence:04003 Camera:5 Frame:009[60]
# ]

# %%
meta.models.ImageCollection.objects.all()[0]
# Out:
# id: 1
# service: serviceinstance - tasks.add_sample_images [2]
# name: Purdue Dataset Camera 0
# objectId: 3c445a0b-770b-4b41-85e1-cabcc4c03ac0
# newerVersion: None
# deleted: False
# images
#   Purdue Data Date:20100427161936 Sequence:04003 Camera:0 Frame:000[1]
#   Purdue Data Date:20100427161937 Sequence:04003 Camera:0 Frame:001[7]
#   Purdue Data Date:20100427161937 Sequence:04003 Camera:0 Frame:002[13]
#   Purdue Data Date:20100427161938 Sequence:04003 Camera:0 Frame:003[19]
#   Purdue Data Date:20100427161939 Sequence:04003 Camera:0 Frame:004[25]
#   Purdue Data Date:20100427161940 Sequence:04003 Camera:0 Frame:005[31]
#   Purdue Data Date:20100427161941 Sequence:04003 Camera:0 Frame:006[37]
#   Purdue Data Date:20100427161941 Sequence:04003 Camera:0 Frame:007[43]
#   Purdue Data Date:20100427161942 Sequence:04003 Camera:0 Frame:008[49]
#   Purdue Data Date:20100427161943 Sequence:04003 Camera:0 Frame:009[55]
